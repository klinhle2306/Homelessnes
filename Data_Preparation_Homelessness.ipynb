# %% [markdown]
# <a href="https://colab.research.google.com/github/klinhle2306/Homelessness/blob/main/Data_Preparation_Homelessness.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Introduction

# %% [markdown]
#   The 2020 [point-in-time count](https://www.kingcounty.gov/elected/executive/constantine/news/release/2020/July/01-homeless-count.aspx) of people experiencing homelessness for Seattle/King County was 11,751. This represents a 5% increase over the 2019 count and reflects similar trend across many counties in the western U.S..
#
#   The U.S. Department of Housing and Urban Development (HUD) produced a report in 2019 [Market Predictors of Homelessness](https://www.huduser.gov/portal/sites/default/files/pdf/Market-Predictors-of-Homelessness.pdf) that describes a model-based approach to understanding of the relationship between local housing market factors and homelessness.
#
#   This project investigates whether there are alternative modeling approaches that outperform the models described in the HUD report.

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style='whitegrid')
import missingno as msno

# Train-test splits
from sklearn.model_selection import train_test_split

# Model preprocessing
from sklearn.preprocessing import StandardScaler

import statsmodels.api as sm


# Imputation
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import SimpleImputer, IterativeImputer, KNNImputer

# %% [markdown]
# ## The data

# %% [markdown]
#
#   The [data](https://github.com/brian-fischer/DATA-3320/blob/main/homelessness/05b_analysis_file_update.csv) for this project are described in HUD's report [Market Predictors of Homelessness](https://www.huduser.gov/portal/sites/default/files/pdf/Market-Predictors-of-Homelessness.pdf) in the section titled DATA.
#
#   The data dictionary [HUD TO3 - 05b Analysis File - Data Dictionary.csv](https://github.com/brian-fischer/DATA-3320/blob/main/homelessness/HUD%20TO3%20-%2005b%20Analysis%20File%20-%20Data%20-%20Dictionary.csv) contains descriptions of all variables in the data set.

# %% [markdown]
# ## Load the data

# %%
df = pd.read_csv('https://raw.githubusercontent.com/klinhle2306/Homelessness/main/05b_analysis_file_update.csv')

# %%
dictionary = pd.read_csv('https://raw.githubusercontent.com/klinhle2306/Homelessness/main/HUD%20TO3%20-%2005b%20Analysis%20File%20-%20Data%20-%20Dictionary.csv')

# %% [markdown]
# ## Explore the contents of the data set

# %% [markdown]
# Identify predictor variables and target variables

# %%
df.head()
# Out:
#    year cocnumber  pit_tot_shelt_pit_hud  pit_tot_unshelt_pit_hud  \
# 0  2010    AK-500                 1113.0                    118.0
# 1  2011    AK-500                 1082.0                    141.0
# 2  2012    AK-500                 1097.0                     50.0
# 3  2013    AK-500                 1070.0                     52.0
# 4  2014    AK-500                  970.0                     53.0
#
#    pit_tot_hless_pit_hud  pit_ind_shelt_pit_hud  pit_ind_unshelt_pit_hud  \
# 0                 1231.0                  633.0                    107.0
# 1                 1223.0                  677.0                    117.0
# 2                 1147.0                  756.0                     35.0
# 3                 1122.0                  792.0                     52.0
# 4                 1023.0                  688.0                     48.0
#
#    pit_ind_hless_pit_hud  pit_perfam_shelt_pit_hud  \
# 0                  740.0                     480.0
# 1                  794.0                     405.0
# 2                  791.0                     341.0
# 3                  844.0                     278.0
# 4                  736.0                     282.0
#
#    pit_perfam_unshelt_pit_hud  ...  sub_high_cost_rent75  \
# 0                        11.0  ...                     1
# 1                        24.0  ...                     1
# 2                        15.0  ...                     1
# 3                         0.0  ...                     1
# 4                         5.0  ...                     1
#
#    sub_high_cost_homeval75  sub_high_rent_share75  tight_high_cost_rental_mkt  \
# 0                        1                      1                           3
# 1                        1                      0                           3
# 2                        1                      1                           3
# 3                        1                      0                           3
# 4                        1                      1                           3
#
#    sub_tight_high_cost_rent  sub_west_coast_all_urb  sub_west_census  \
# 0                         1                       1                1
# 1                         1                       1                1
# 2                         1                       1                1
# 3                         1                       1                1
# 4                         1                       1                1
#
#    major_city  suburban  rural
# 0           1         0      0
# 1           1         0      0
# 2           1         0      0
# 3           1         0      0
# 4           1         0      0
#
# [5 rows x 332 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3008 entries, 0 to 3007
# Columns: 332 entries, year to rural
# dtypes: float64(257), int64(73), object(2)
# memory usage: 7.6+ MB

# %% [markdown]
# Observe that this is a large dataset with 332 different variable. This will make it difficult to understand and analyze the data effectively.

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3008 entries, 0 to 3007
# Data columns (total 332 columns):
#  #    Column                            Dtype
# ---   ------                            -----
#  0    year                              int64
#  1    cocnumber                         object
#  2    pit_tot_shelt_pit_hud             float64
#  3    pit_tot_unshelt_pit_hud           float64
#  4    pit_tot_hless_pit_hud             float64
#  5    pit_ind_shelt_pit_hud             float64
#  6    pit_ind_unshelt_pit_hud           float64
#  7    pit_ind_hless_pit_hud             float64
#  8    pit_perfam_shelt_pit_hud          float64
#  9    pit_perfam_unshelt_pit_hud        float64
#  10   pit_perfam_hless_pit_hud          float64
#  11   pit_ind_chronic_hless_pit_hud     float64
#  12   pit_perfam_chronic_hless_pit_hud  float64
#  13   pit_vet_hless_pit_hud             float64
#  14   econ_urb_urbanicity               int64
#  15   coctag                            int64
#  16   panelvar                          int64
#  17   hou_pol_totalind_hud              float64
#  18   hou_pol_totalday_hud              float64
#  19   hou_pol_totalexit_hud             float64
#  20   hou_pol_numret6mos_hud            float64
#  21   hou_pol_numret12mos_hud           float64
#  22   hou_pol_fedfundcoc                float64
#  23   hou_pol_fund_project              float64
#  24   hou_pol_bed_es_hic_hud            float64
#  25   hou_pol_bed_oph_hic_hud           float64
#  26   hou_pol_bed_psh_hic_hud           float64
#  27   hou_pol_bed_rrh_hic_hud           float64
#  28   hou_pol_bed_sh_hic_hud            float64
#  29   hou_pol_bed_th_hic_hud            float64
#  30   hou_pol_perm_bed_hic_hud          float64
#  31   hou_pol_temp_bed_hic_hud          float64
#  32   dem_pop_pop_census                int64
#  33   dem_pop_male_census               int64
#  34   dem_pop_female_census             int64
#  35   dem_pop_child_census              int64
#  36   dem_pop_adult_census              int64
#  37   dem_pop_senior_census             int64
#  38   dem_soc_white_census              int64
#  39   dem_soc_black_census              int64
#  40   dem_soc_native_census             int64
#  41   dem_soc_asian_census              int64
#  42   dem_soc_pacific_census            int64
#  43   dem_soc_racetwo_census            int64
#  44   dem_soc_hispanic_census           int64
#  45   dem_age_boom_census               float64
#  46   total_rent_inventory_acs5yr       float64
#  47   dem_soc_ed_bach_acs5yr            float64
#  48   dem_soc_ed_hsgrad_acs5yr          float64
#  49   dem_soc_ed_lesshs_acs5yr          float64
#  50   dem_soc_ed_somecoll_acs5yr        float64
#  51   dem_soc_vet_acs5yr                float64
#  52   dem_soc_singparent_acs5yr         float64
#  53   dem_health_ins_acs5yr             float64
#  54   econ_labor_topskilled_acs5yr      float64
#  55   econ_labor_midskilled_acs5yr      float64
#  56   econ_labor_unskilled_acs5yr       float64
#  57   econ_labor_incineq_acs5yr         float64
#  58   econ_labor_medinc_acs5yr          float64
#  59   econ_labor_pov_acs5yr             float64
#  60   dem_soc_singadult_acs5yr          float64
#  61   econ_sn_cashasst_acs5yr           float64
#  62   hou_mkt_homeval_acs5yr            float64
#  63   hou_mkt_homeage_acs5yr            float64
#  64   hou_mkt_homeage1940_acs5yr        float64
#  65   hou_mkt_medrent_acs5yr            float64
#  66   hou_mkt_medrentgross_acs5yr       float64
#  67   hou_mkt_ovrcrowd_acs5yr           float64
#  68   hou_mkt_rentshare_acs5yr          float64
#  69   hou_mkt_rentvacancy_acs5yr        float64
#  70   hou_mkt_utility_acs5yr            float64
#  71   hou_mkt_burden_own_acs5yr         float64
#  72   hou_mkt_burden_sev_own_acs5yr     float64
#  73   hou_mkt_burden_rent_acs5yr        float64
#  74   hou_mkt_burden_sev_rent_acs5yr    float64
#  75   fhfa_hpi_flag                     int64
#  76   fhfa_hpi_2009                     float64
#  77   econ_labor_force_pop_BLS          int64
#  78   econ_labor_emp_pop_BLS            int64
#  79   econ_labor_unemp_pop_BLS          int64
#  80   econ_labor_unemp_rate_BLS         float64
#  81   hou_mkt_area_census               float64
#  82   dem_pop_density_census            float64
#  83   hou_mkt_density_census            float64
#  84   dem_pop_mig_census                int64
#  85   hou_pol_hudunit_psh_hud           int64
#  86   hou_pol_occhudunit_psh_hud        float64
#  87   hou_mkt_pplunit_psh_hud           float64
#  88   hou_pol_eli_psh_hud               float64
#  89   hou_mkt_pctoverhouse_psh_hud      float64
#  90   hou_mkt_units_census              int64
#  91   hou_mkt_pmt_totbldg_census        int64
#  92   hou_mkt_pmt_totunit_census        int64
#  93   hou_mkt_pmt_totvalue_census       int64
#  94   econ_labor_pov_pop_census         int64
#  95   econ_labor_medinc_census          float64
#  96   econ_sn_ssdi_SSA                  int64
#  97   econ_sn_ssdi_part_rate_SSA        float64
#  98   econ_sn_ssi_part_SSA              int64
#  99   econ_sn_ssi_pay_SSA               int64
#  100  econ_sn_ssi_part_rate_SSA         float64
#  101  hou_mkt_evict_count               int64
#  102  hou_mkt_evict_file_count          int64
#  103  hou_mkt_renter_count_evlab        int64
#  104  hou_mkt_evict_flag                int64
#  105  hou_mkt_evict_file_rate           float64
#  106  hou_mkt_evict_rate                float64
#  107  dem_health_alcoholdeath_IMHE      float64
#  108  dem_mort_lifeexp_IMHE             float64
#  109  econ_sn_eitc_irs                  float64
#  110  econ_sn_returns_irs               float64
#  111  econ_sn_eitc_irs_share            float64
#  112  dem_health_mentalhlth_chr         float64
#  113  dem_health_excesdrink_chr         float64
#  114  dem_health_cost_dart              float64
#  115  hou_pol_hlessconduct_food         int64
#  116  hou_pol_hlessconduct_total        int64
#  117  hou_pol_hlessconduct_sleep        int64
#  118  hou_pol_hlessconduct_loiter       int64
#  119  hou_pol_hlessconduct_beg          int64
#  120  env_wea_avgtemp_summer_noaa       float64
#  121  env_wea_precip_annual_noaa        float64
#  122  cpi_2017                          float64
#  123  env_wea_avgtemp_noaa              float64
#  124  env_wea_precip_noaa               float64
#  125  state_abr                         object
#  126  pit_miss                          int64
#  127  odd_flag                          int64
#  128  pit_hless_balance                 int64
#  129  pit_shelt_balance                 int64
#  130  pit_unshelt_balance               int64
#  131  unbalance_flag                    int64
#  132  pit_shelt_pit_hud_share           float64
#  133  pit_unshelt_pit_hud_share         float64
#  134  pit_hless_pit_hud_share           float64
#  135  missing                           int64
#  136  dem_pop_adult_census_share        float64
#  137  dem_pop_child_census_share        float64
#  138  dem_pop_female_census_share       float64
#  139  dem_pop_male_census_share         float64
#  140  dem_pop_mig_census_share          float64
#  141  dem_pop_senior_census_share       float64
#  142  dem_age_boom_census_2011          float64
#  143  dem_soc_asian_census_share        float64
#  144  dem_soc_black_census_share        float64
#  145  dem_soc_hispanic_census_share     float64
#  146  dem_soc_native_census_share       float64
#  147  dem_soc_pacific_census_share      float64
#  148  dem_soc_racetwo_census_share      float64
#  149  dem_soc_white_census_share        float64
#  150  dem_soc_other_census_share        float64
#  151  dem_health_mentalhlth_chr_share   float64
#  152  dem_health_mhlth_chr_share_2017   float64
#  153  dem_health_excesdrink_chr_2017    float64
#  154  dem_health_alcdeath_IMHE_2015     float64
#  155  dem_mort_lifeexp_IMHE_2015        float64
#  156  dem_health_ins_acs5yr_2012        float64
#  157  dem_health_ins_acs5yr_2017        float64
#  158  dem_soc_ed_bach_acs5yr_2012       float64
#  159  dem_soc_ed_bach_acs5yr_2017       float64
#  160  dem_soc_ed_bach_acs5yr_diff       float64
#  161  dem_soc_ed_somecoll_acs5yr_2012   float64
#  162  dem_soc_ed_somecoll_acs5yr_2017   float64
#  163  dem_soc_ed_hsgrad_acs5yr_2012     float64
#  164  dem_soc_ed_hsgrad_acs5yr_2017     float64
#  165  dem_soc_ed_lesshs_acs5yr_2012     float64
#  166  dem_soc_ed_lesshs_acs5yr_2017     float64
#  167  dem_soc_ed_lesshs_acs5yr_diff     float64
#  168  dem_soc_singparent_acs5yr_2012    float64
#  169  dem_soc_singparent_acs5yr_2017    float64
#  170  dem_soc_singparent_acs5yr_diff    float64
#  171  dem_soc_singadult_acs5yr_2012     float64
#  172  dem_soc_singadult_acs5yr_2017     float64
#  173  dem_soc_singadult_acs5yr_diff     float64
#  174  dem_soc_vet_acs5yr_2012           float64
#  175  dem_soc_vet_acs5yr_2017           float64
#  176  dem_soc_vet_acs5yr_diff           float64
#  177  econ_labor_incineq_acs5yr_2012    float64
#  178  econ_labor_incineq_acs5yr_2017    float64
#  179  econ_labor_incineq_acs5yr_diff    float64
#  180  econ_labor_topskill_acs5yr_2012   float64
#  181  econ_labor_topskill_acs5yr_2017   float64
#  182  econ_labor_topskill_acs5yr_diff   float64
#  183  econ_labor_midskill_acs5yr_2012   float64
#  184  econ_labor_midskill_acs5yr_2017   float64
#  185  econ_labor_midskill_acs5yr_diff   float64
#  186  econ_labor_unskill_acs5yr_2012    float64
#  187  econ_labor_unskill_acs5yr_2017    float64
#  188  econ_labor_unskill_acs5yr_diff    float64
#  189  econ_labor_medinc_acs5yr_2012     float64
#  190  econ_labor_medinc_acs5yr_2017     float64
#  191  econ_labor_pov_pop_census_share   float64
#  192  econ_sn_cashasst_acs5yr_2012      float64
#  193  econ_sn_cashasst_acs5yr_2017      float64
#  194  econ_sn_cashasst_acs5yr_diff      float64
#  195  hou_mkt_rentshare_acs5yr_2012     float64
#  196  hou_mkt_rentshare_acs5yr_2017     float64
#  197  hou_mkt_rentshare_acs5yr_diff     float64
#  198  hou_mkt_rentvacancy_acs5yr_2012   float64
#  199  hou_mkt_rentvacancy_acs5yr_2017   float64
#  200  hou_mkt_rentvacancy_acs5yr_diff   float64
#  201  hou_mkt_ovrcrowd_acs5yr_2012      float64
#  202  hou_mkt_ovrcrowd_acs5yr_2017      float64
#  203  hou_mkt_ovrcrowd_acs5yr_diff      float64
#  204  hou_mkt_homeage_acs5yr_2012       float64
#  205  hou_mkt_homeage_acs5yr_2017       float64
#  206  hou_mkt_homeage_acs5yr_diff       float64
#  207  hou_mkt_homeage1940_acs5yr_2012   float64
#  208  hou_mkt_homeage1940_acs5yr_2017   float64
#  209  hou_mkt_homeage1940_acs5yr_diff   float64
#  210  hou_mkt_homeval_acs5yr_2012       float64
#  211  hou_mkt_homeval_acs5yr_2017       float64
#  212  hou_mkt_homeval_acs5yr_diff       float64
#  213  hou_mkt_medrent_acs5yr_2012       float64
#  214  hou_mkt_medrent_acs5yr_2017       float64
#  215  hou_mkt_medrent_acs5yr_diff       float64
#  216  hou_mkt_utility_acs5yr_2012       float64
#  217  hou_mkt_utility_acs5yr_2017       float64
#  218  hou_mkt_utility_acs5yr_diff       float64
#  219  hou_mkt_burden_own_acs5yr_2012    float64
#  220  hou_mkt_burden_own_acs5yr_2017    float64
#  221  hou_mkt_burden_own_acs5yr_diff    float64
#  222  hou_mkt_burden_sev_own_acs_2012   float64
#  223  hou_mkt_burden_sev_own_acs_2017   float64
#  224  hou_mkt_burden_sev_own_acs_diff   float64
#  225  hou_mkt_burden_rent_acs5yr_2012   float64
#  226  hou_mkt_burden_rent_acs5yr_2017   float64
#  227  hou_mkt_burden_rent_acs5yr_diff   float64
#  228  hou_mkt_burden_sev_rent_acs_2012  float64
#  229  hou_mkt_burden_sev_rent_acs_2017  float64
#  230  hou_mkt_burden_sev_rent_acs_diff  float64
#  231  hou_pol_hudunit_psh_hud_share     float64
#  232  hou_mkt_pmt_unit_census_share     float64
#  233  urban_cat                         int64
#  234  state                             int64
#  235  evict_file_flag                   int64
#  236  evict_flag                        int64
#  237  fedfundcoc_flag                   int64
#  238  hou_mkt_density_dummy             int64
#  239  hou_mkt_homeval_xt                float64
#  240  hou_mkt_burden_own_xt             float64
#  241  hou_mkt_burden_sev_own_xt         float64
#  242  hou_mkt_burden_rent_xt            float64
#  243  hou_mkt_burden_sev_rent_xt        float64
#  244  hou_mkt_homeage_xt                float64
#  245  hou_mkt_homeage1940_xt            float64
#  246  hou_mkt_medrent_xt                float64
#  247  hou_mkt_utility_xt                float64
#  248  hou_mkt_rentshare_xt              float64
#  249  hou_mkt_rentvacancy_xt            float64
#  250  hou_mkt_ovrcrowd_xt               float64
#  251  econ_labor_midskill_xt            float64
#  252  econ_labor_incineq_xt             float64
#  253  econ_sn_cashasst_xt               float64
#  254  dem_soc_ed_bach_xt                float64
#  255  dem_soc_ed_somecoll_xt            float64
#  256  dem_soc_ed_hsgrad_xt              float64
#  257  dem_soc_ed_lesshs_xt              float64
#  258  dem_health_ins_xt                 float64
#  259  dem_soc_singadult_xt              float64
#  260  dem_soc_singparent_xt             float64
#  261  dem_soc_vet_xt                    float64
#  262  ln_hou_mkt_homeval_xt             float64
#  263  ln_hou_mkt_medrent_xt             float64
#  264  ln_econ_labor_medinc_census       float64
#  265  flag_d_hless                      int64
#  266  flag_xt_hless                     int64
#  267  flag_d_shelt                      int64
#  268  flag_xt_shelt                     int64
#  269  flag_d_unshelt                    int64
#  270  flag_xt_unshelt                   int64
#  271  d_pit_hless_pit_hud_share         float64
#  272  d_pit_shelt_pit_hud_share         float64
#  273  d_pit_unshelt_pit_hud_share       float64
#  274  d_hou_mkt_homeval_xt              float64
#  275  d_hou_mkt_burden_sev_rent_xt      float64
#  276  d_hou_mkt_burden_own_xt           float64
#  277  d_hou_mkt_burden_sev_own_xt       float64
#  278  d_hou_mkt_burden_rent_xt          float64
#  279  d_hou_mkt_medrent_xt              float64
#  280  d_hou_mkt_utility_xt              float64
#  281  d_fhfa_hpi_2009                   float64
#  282  d_hou_mkt_homeage1940_xt          float64
#  283  d_hou_mkt_rentshare_xt            float64
#  284  d_hou_mkt_rentvacancy_xt          float64
#  285  d_hou_mkt_ovrcrowd_xt             float64
#  286  d_hou_mkt_pctoverhouse_psh_hud    float64
#  287  d_hou_mkt_evict_rate              float64
#  288  d_hou_pol_eli_psh_hud             float64
#  289  d_hou_pol_hudunit_psh_hud_share   float64
#  290  d_hou_pol_occhudunit_psh_hud      float64
#  291  d_hou_pol_fedfundcoc              float64
#  292  d_econ_labor_medinc_census        float64
#  293  d_econ_labor_unemp_rate_BLS       float64
#  294  d_econ_labor_incineq_xt           float64
#  295  d_econ_sn_cashasst_xt             float64
#  296  d_econ_sn_eitc_irs_share          float64
#  297  d_econ_sn_ssdi_part_rate_SSA      float64
#  298  d_econ_sn_ssi_part_rate_SSA       float64
#  299  d_dem_soc_white_census_share      float64
#  300  d_dem_soc_black_census_share      float64
#  301  d_dem_soc_hispanic_census_share   float64
#  302  d_dem_soc_asian_census_share      float64
#  303  d_dem_pop_child_census_share      float64
#  304  d_dem_pop_adult_census_share      float64
#  305  d_dem_pop_senior_census_share     float64
#  306  d_dem_pop_female_census_share     float64
#  307  d_dem_pop_mig_census_share        float64
#  308  d_dem_soc_ed_bach_xt              float64
#  309  d_dem_health_cost_dart            float64
#  310  d_dem_soc_singadult_xt            float64
#  311  d_dem_soc_singparent_xt           float64
#  312  d_dem_soc_vet_xt                  float64
#  313  d_env_wea_avgtemp_noaa            float64
#  314  d_env_wea_avgtemp_summer_noaa     float64
#  315  d_env_wea_precip_noaa             float64
#  316  d_env_wea_precip_annual_noaa      float64
#  317  dem_soc_ed_lessbach_xt            float64
#  318  census_region                     int64
#  319  census_division                   int64
#  320  sub_west_coast                    int64
#  321  sub_low_rent_vacancy              int64
#  322  sub_high_cost_rent75              int64
#  323  sub_high_cost_homeval75           int64
#  324  sub_high_rent_share75             int64
#  325  tight_high_cost_rental_mkt        int64
#  326  sub_tight_high_cost_rent          int64
#  327  sub_west_coast_all_urb            int64
#  328  sub_west_census                   int64
#  329  major_city                        int64
#  330  suburban                          int64
#  331  rural                             int64
# dtypes: float64(257), int64(73), object(2)
# memory usage: 7.6+ MB

# %%
dictionary
# Out:
#     Associated Domain                 Variable  \
# 0          Identifier                     year
# 1          Identifier                cocnumber
# 2             Outcome    pit_tot_shelt_pit_hud
# 3             Outcome  pit_tot_unshelt_pit_hud
# 4             Outcome    pit_tot_hless_pit_hud
# ..                ...                      ...
# 327          Subgroup   sub_west_coast_all_urb
# 328          Subgroup          sub_west_census
# 329          Subgroup               major_city
# 330          Subgroup                 suburban
# 331          Subgroup                    rural
#
#                                         Variable Label Derived  \
# 0                                                 year      No
# 1                             continuum of care number      No
# 2                            total sheltered - HUD PIT      No
# 3                          total unsheltered - HUD PIT      No
# 4                             total homeless - HUD PIT      No
# ..                                                 ...     ...
# 327  indicator for suburban or major city/largely u...      No
# 328                     indicator for west region CoCs      No
# 329      indicator for major city or largely urban CoC      No
# 330                 indicator for largely suburban CoC      No
# 331                    indicator for largely rural CoC      No
#
#     Source or Root Variable Table Name(s)
# 0                       NaN           NaN
# 1                       HUD           NaN
# 2                   HUD PIT           NaN
# 3                   HUD PIT           NaN
# 4                   HUD PIT           NaN
# ..                      ...           ...
# 327                     NaN           NaN
# 328                     NaN           NaN
# 329                     HUD           NaN
# 330                     HUD           NaN
# 331                     HUD           NaN
#
# [332 rows x 6 columns]

# %% [markdown]
# ### Explore the data sources

# %% [markdown]
# Use the dictionary to find the unique `Associated Domain` values.

# %%
dictionary['Associated Domain'].unique()
# Out:
# array(['Identifier', 'Outcome', 'Secondary Outcome', 'Subgroup',
#        'Safety Net', 'Demographic', 'Housing', 'Economic', 'Local Policy',
#        'Climate', 'Geography'], dtype=object)

# %% [markdown]
# A bar graph that shows the counts of different associated domains.

# %%
dictionary['Associated Domain'].value_counts().plot(kind='barh')
plt.gca().invert_yaxis()

plt.xlabel('Count', fontsize=18)
plt.title('Associated Domains', fontsize=20);

# %% [markdown]
# A bar graph that shows the counts of different data sources described in `Source or Root Variable`.

# %%
dictionary['Source or Root Variable'].value_counts().head(10).plot(kind='barh')
plt.gca().invert_yaxis()

plt.xlabel('Count', fontsize=18)
plt.title('Data Sources', fontsize=20);

# %% [markdown]
# ## Select relevant subsets of the data

# %%
columns_to_keep = ["year", "cocnumber",
  
                  "pit_tot_hless_pit_hud", "pit_tot_shelt_pit_hud", "pit_tot_unshelt_pit_hud","dem_pop_pop_census",
  
                  "fhfa_hpi_2009", "ln_hou_mkt_medrent_xt", "hou_mkt_utility_xt", "hou_mkt_burden_own_acs5yr_2017", "hou_mkt_burden_sev_rent_acs_2017", "hou_mkt_rentshare_acs5yr_2017", "hou_mkt_rentvacancy_xt", "hou_mkt_density_dummy", "hou_mkt_evict_count", "hou_mkt_ovrcrowd_acs5yr_2017", "major_city", "suburban",
           
                  "econ_labor_unemp_rate_BLS", "econ_labor_incineq_acs5yr_2017", "econ_labor_pov_pop_census_share",
           
                  "hou_pol_hudunit_psh_hud_share", "hou_pol_occhudunit_psh_hud", "hou_mkt_homeage1940_xt",
           
                  "dem_soc_black_census", "dem_soc_hispanic_census", "dem_soc_asian_census", "dem_soc_pacific_census", "dem_pop_child_census", "dem_pop_senior_census", "dem_pop_female_census", "dem_pop_mig_census", "d_dem_pop_mig_census_share", "dem_soc_singadult_xt", "dem_soc_singparent_xt", "dem_soc_vet_xt", "dem_soc_ed_lessbach_xt", "dem_health_cost_dart", "dem_health_excesdrink_chr",
           
                  "env_wea_avgtemp_noaa", "env_wea_avgtemp_summer_noaa", "env_wea_precip_noaa", "env_wea_precip_annual_noaa", "hou_pol_fedfundcoc", "d_hou_pol_fedfundcoc"]

# %%
df = df[columns_to_keep]

# %%
df.head()
# Out:
#    year cocnumber  pit_tot_hless_pit_hud  pit_tot_shelt_pit_hud  \
# 0  2010    AK-500                 1231.0                 1113.0
# 1  2011    AK-500                 1223.0                 1082.0
# 2  2012    AK-500                 1147.0                 1097.0
# 3  2013    AK-500                 1122.0                 1070.0
# 4  2014    AK-500                 1023.0                  970.0
#
#    pit_tot_unshelt_pit_hud  dem_pop_pop_census  fhfa_hpi_2009  \
# 0                    118.0              285194       0.000000
# 1                    141.0              293370       0.009359
# 2                     50.0              296291      -0.049137
# 3                     52.0              298520      -0.255042
# 4                     53.0              301081       3.170481
#
#    ln_hou_mkt_medrent_xt  hou_mkt_utility_xt  hou_mkt_burden_own_acs5yr_2017  \
# 0                    NaN                 NaN                       15.334315
# 1               2.266958                 9.3                       15.334315
# 2                    NaN                 NaN                       15.334315
# 3               2.266958                 9.3                       15.334315
# 4                    NaN                 NaN                       15.334315
#
#    ...  dem_soc_vet_xt  dem_soc_ed_lessbach_xt  dem_health_cost_dart  \
# 0  ...             NaN                     NaN               7.78885
# 1  ...        17.23423               66.952057               7.85001
# 2  ...             NaN                     NaN               7.90594
# 3  ...        17.23423               66.952057               7.83198
# 4  ...             NaN                     NaN               7.95718
#
#    dem_health_excesdrink_chr  env_wea_avgtemp_noaa  \
# 0                        NaN             18.400000
# 1                        NaN             18.799999
# 2                        NaN              2.900000
# 3                        NaN             23.299999
# 4                        NaN             30.299999
#
#    env_wea_avgtemp_summer_noaa  env_wea_precip_noaa  \
# 0                    56.599998                 0.68
# 1                    55.799999                 0.52
# 2                    55.900002                 1.17
# 3                    56.000000                 1.10
# 4                    60.099998                 1.52
#
#    env_wea_precip_annual_noaa  hou_pol_fedfundcoc  d_hou_pol_fedfundcoc
# 0                   12.560000            25.98005                   NaN
# 1                   15.560000            27.17670                   NaN
# 2                   16.459999            30.01799                   NaN
# 3                   20.270000            29.96026                   NaN
# 4                   24.010000            27.86784                   NaN
#
# [5 rows x 45 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3008 entries, 0 to 3007
# Data columns (total 45 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   year                              3008 non-null   int64
#  1   cocnumber                         3008 non-null   object
#  2   pit_tot_hless_pit_hud             2994 non-null   float64
#  3   pit_tot_shelt_pit_hud             2994 non-null   float64
#  4   pit_tot_unshelt_pit_hud           2994 non-null   float64
#  5   dem_pop_pop_census                3008 non-null   int64
#  6   fhfa_hpi_2009                     3008 non-null   float64
#  7   ln_hou_mkt_medrent_xt             1504 non-null   float64
#  8   hou_mkt_utility_xt                1504 non-null   float64
#  9   hou_mkt_burden_own_acs5yr_2017    3008 non-null   float64
#  10  hou_mkt_burden_sev_rent_acs_2017  3008 non-null   float64
#  11  hou_mkt_rentshare_acs5yr_2017     3008 non-null   float64
#  12  hou_mkt_rentvacancy_xt            1504 non-null   float64
#  13  hou_mkt_density_dummy             3008 non-null   int64
#  14  hou_mkt_evict_count               3008 non-null   int64
#  15  hou_mkt_ovrcrowd_acs5yr_2017      3008 non-null   float64
#  16  major_city                        3008 non-null   int64
#  17  suburban                          3008 non-null   int64
#  18  econ_labor_unemp_rate_BLS         3008 non-null   float64
#  19  econ_labor_incineq_acs5yr_2017    3008 non-null   float64
#  20  econ_labor_pov_pop_census_share   3008 non-null   float64
#  21  hou_pol_hudunit_psh_hud_share     3008 non-null   float64
#  22  hou_pol_occhudunit_psh_hud        3008 non-null   float64
#  23  hou_mkt_homeage1940_xt            1504 non-null   float64
#  24  dem_soc_black_census              3008 non-null   int64
#  25  dem_soc_hispanic_census           3008 non-null   int64
#  26  dem_soc_asian_census              3008 non-null   int64
#  27  dem_soc_pacific_census            3008 non-null   int64
#  28  dem_pop_child_census              3008 non-null   int64
#  29  dem_pop_senior_census             3008 non-null   int64
#  30  dem_pop_female_census             3008 non-null   int64
#  31  dem_pop_mig_census                3008 non-null   int64
#  32  d_dem_pop_mig_census_share        376 non-null    float64
#  33  dem_soc_singadult_xt              1504 non-null   float64
#  34  dem_soc_singparent_xt             1504 non-null   float64
#  35  dem_soc_vet_xt                    1504 non-null   float64
#  36  dem_soc_ed_lessbach_xt            1504 non-null   float64
#  37  dem_health_cost_dart              3008 non-null   float64
#  38  dem_health_excesdrink_chr         376 non-null    float64
#  39  env_wea_avgtemp_noaa              3008 non-null   float64
#  40  env_wea_avgtemp_summer_noaa       3006 non-null   float64
#  41  env_wea_precip_noaa               3008 non-null   float64
#  42  env_wea_precip_annual_noaa        3008 non-null   float64
#  43  hou_pol_fedfundcoc                3008 non-null   float64
#  44  d_hou_pol_fedfundcoc              376 non-null    float64
# dtypes: float64(30), int64(14), object(1)
# memory usage: 1.0+ MB

# %%
dictionary_small = dictionary[dictionary['Variable'].isin(columns_to_keep)]

# %%
dictionary_small
# Out:
#     Associated Domain                          Variable  \
# 0          Identifier                              year
# 1          Identifier                         cocnumber
# 2             Outcome             pit_tot_shelt_pit_hud
# 3             Outcome           pit_tot_unshelt_pit_hud
# 4             Outcome             pit_tot_hless_pit_hud
# 22         Safety Net                hou_pol_fedfundcoc
# 32        Demographic                dem_pop_pop_census
# 34        Demographic             dem_pop_female_census
# 35        Demographic              dem_pop_child_census
# 37        Demographic             dem_pop_senior_census
# 39        Demographic              dem_soc_black_census
# 41        Demographic              dem_soc_asian_census
# 42        Demographic            dem_soc_pacific_census
# 44        Demographic           dem_soc_hispanic_census
# 76            Housing                     fhfa_hpi_2009
# 80           Economic         econ_labor_unemp_rate_BLS
# 84        Demographic                dem_pop_mig_census
# 86         Safety Net        hou_pol_occhudunit_psh_hud
# 101           Housing               hou_mkt_evict_count
# 113       Demographic         dem_health_excesdrink_chr
# 114       Demographic              dem_health_cost_dart
# 120           Climate       env_wea_avgtemp_summer_noaa
# 121           Climate        env_wea_precip_annual_noaa
# 123           Climate              env_wea_avgtemp_noaa
# 124           Climate               env_wea_precip_noaa
# 178          Economic    econ_labor_incineq_acs5yr_2017
# 191          Economic   econ_labor_pov_pop_census_share
# 196           Housing     hou_mkt_rentshare_acs5yr_2017
# 202           Housing      hou_mkt_ovrcrowd_acs5yr_2017
# 220           Housing    hou_mkt_burden_own_acs5yr_2017
# 229           Housing  hou_mkt_burden_sev_rent_acs_2017
# 231        Safety Net     hou_pol_hudunit_psh_hud_share
# 238           Housing             hou_mkt_density_dummy
# 245        Safety Net            hou_mkt_homeage1940_xt
# 247           Housing                hou_mkt_utility_xt
# 249           Housing            hou_mkt_rentvacancy_xt
# 259       Demographic              dem_soc_singadult_xt
# 260       Demographic             dem_soc_singparent_xt
# 261       Demographic                    dem_soc_vet_xt
# 263           Housing             ln_hou_mkt_medrent_xt
# 291        Safety Net              d_hou_pol_fedfundcoc
# 307       Demographic        d_dem_pop_mig_census_share
# 317       Demographic            dem_soc_ed_lessbach_xt
# 329          Subgroup                        major_city
# 330          Subgroup                          suburban
#
#                                         Variable Label Derived  \
# 0                                                 year      No
# 1                             continuum of care number      No
# 2                            total sheltered - HUD PIT      No
# 3                          total unsheltered - HUD PIT      No
# 4                             total homeless - HUD PIT      No
# 22                           CoC federal funding - HUD      No
# 32              total population, intercensal estimate      No
# 34       total female population, intercensal estimate      No
# 35    total population ages 0-19, intercensal estimate      No
# 37   total population ages 65 or older, intercensal...      No
# 39   total black alone (non-hispanic) population, i...      No
# 41   total asian alone (non-hispanic) population, i...      No
# 42   total pacific islander alone (non-hispanic) po...      No
# 44   total latino/hispanic (all races) population, ...      No
# 76   2009 base year house price index (HPI), from FHFA      No
# 80                    unemployment rate, from BLS LAUS     Yes
# 84   net migration from year-1 to year, intercensal...      No
# 86                             HUD unit occupancy rate     Yes
# 101  number of addresses with an eviction judgment,...      No
# 113  percentage of adults that report excessive dri...     Yes
# 114  total medicare reimbursements per enrollee (pa...      No
# 120    average summer temperature - June, July, August      No
# 121                         total annual precipitation      No
# 123                        average January temperature      No
# 124                        total January precipitation      No
# 178                              2016 gini coefficient      No
# 191  poverty rate, number of persons in poverty to ...     Yes
# 196                              2016 share of renters     Yes
# 202            2016 share of overcrowded housing units     Yes
# 220    2016 percentage of home owners with cost burden     Yes
# 229  2016 percentage of renters with severe cost bu...     Yes
# 231  share of HUD-subsidized housing units to total...     Yes
# 238  indicator for high housing density CoC (>= 75t...      No
# 245  share of housing structures built before 1940 ...     Yes
# 247  utility costs as the difference of median gros...      No
# 249  rental vacancy rate-share of vacant units for ...     Yes
# 259  proportion of one-person households to all hou...     Yes
# 260  share of under 18 population living with singl...     Yes
# 261  share of the civilian population 25 and older ...     Yes
# 263                                 log of median rent      No
# 291  4-year change in hou_pol_fedfundcoc values (20...      No
# 307  4-year change in dem_pop_mig_census_share valu...     Yes
# 317  share of the population without a bachelors de...     Yes
# 329      indicator for major city or largely urban CoC      No
# 330                 indicator for largely suburban CoC      No
#
#                                Source or Root Variable  \
# 0                                                  NaN
# 1                                                  HUD
# 2                                              HUD PIT
# 3                                              HUD PIT
# 4                                              HUD PIT
# 22                             HUD CoC Funding Reports
# 32             Census Intercensal Population Estimates
# 34             Census Intercensal Population Estimates
# 35             Census Intercensal Population Estimates
# 37             Census Intercensal Population Estimates
# 39             Census Intercensal Population Estimates
# 41             Census Intercensal Population Estimates
# 42             Census Intercensal Population Estimates
# 44             Census Intercensal Population Estimates
# 76                      Federal Housing Finance Agency
# 80       BLS Local Area Unemployment Statistics (LAUS)
# 84              Census Intercensal Migration Estimates
# 86                HUD Picture of Subsidized Households
# 101               Eviction Lab at Princeton University
# 113  University of Wisconsin County Health Rankings...
# 114                 The Dartmouth Atlas of Health Care
# 120     NOAA nClimDiv\nNOAA Climate at a Glance System
# 121     NOAA nClimDiv\nNOAA Climate at a Glance System
# 123     NOAA nClimDiv\nNOAA Climate at a Glance System
# 124     NOAA nClimDiv\nNOAA Climate at a Glance System
# 178                      See econ_labor_incineq_acs5yr
# 191  Census Small Area Income and Poverty Estimates...
# 196                       See hou_mkt_rentshare_acs5yr
# 202                        See hou_mkt_ovrcrowd_acs5yr
# 220                      See hou_mkt_burden_own_acs5yr
# 229                 See hou_mkt_burden_sev_rent_acs5yr
# 231  HUD Picture of Subsidized Households\nCensus H...
# 238                                                NaN
# 245                     See hou_mkt_homeage1940_acs5yr
# 247                         See hou_mkt_utility_acs5yr
# 249                     See hou_mkt_rentvacancy_acs5yr
# 259                       See dem_soc_singadult_acs5yr
# 260                      See dem_soc_singparent_acs5yr
# 261                             See dem_soc_vet_acs5yr
# 263                         See hou_mkt_medrent_acs5yr
# 291                             See hou_pol_fedfundcoc
# 307                       See dem_pop_mig_census_share
# 317                        Census ACS 5-Year Estimates
# 329                                                HUD
# 330                                                HUD
#
#                                          Table Name(s)
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 22                                                 NaN
# 32   "Annual County Resident Population Estimates b...
# 34   "Annual County Resident Population Estimates b...
# 35   "Annual County Resident Population Estimates b...
# 37   "Annual County Resident Population Estimates b...
# 39   "Annual County Resident Population Estimates b...
# 41   "Annual County Resident Population Estimates b...
# 42   "Annual County Resident Population Estimates b...
# 44   "Annual County Resident Population Estimates b...
# 76   "HPI for Counties (All-Transactions Index), Ex...
# 80   "Labor Force Data by County, [year] Annual Ave...
# 84   "Annual Resident Population Estimates, Estimat...
# 86                                County-level extract
# 101                                                NaN
# 113                       "2018 CHR CSV Analytic Data"
# 114  Longitudinal research files: Medicare spending...
# 120  nClimDiV COUNTY TEMPERATURE-PRECIPITATION, fro...
# 121  nClimDiV COUNTY TEMPERATURE-PRECIPITATION, fro...
# 123  nClimDiV COUNTY TEMPERATURE-PRECIPITATION, fro...
# 124  nClimDiV COUNTY TEMPERATURE-PRECIPITATION, fro...
# 178                                                NaN
# 191  Income and Poverty Interactive Data Tool, http...
# 196                                                NaN
# 202                                                NaN
# 220                                                NaN
# 229                                                NaN
# 231  County-level extract (HUD Picture of Subsidize...
# 238                                                NaN
# 245                                                NaN
# 247                                                NaN
# 249                                                NaN
# 259                                                NaN
# 260                                                NaN
# 261                                                NaN
# 263                                                NaN
# 291                                                NaN
# 307                                                NaN
# 317  "B23006: EDUCATIONAL ATTAINMENT BY EMPLOYMENT ...
# 329                                                NaN
# 330                                                NaN

# %% [markdown]
# A bar graph that shows how many variables of each Associated Domain are in the smaller data set

# %%
dictionary_small['Associated Domain'].value_counts().plot(kind='barh')
plt.gca().invert_yaxis()

plt.xlabel('Count', fontsize=18)
plt.title('Associated Domains', fontsize=20);

# %% [markdown]
# A bar graph that shows the data sources in the smaller data set

# %%
dictionary_small['Source or Root Variable'].value_counts().head(10).plot(kind='barh')
plt.gca().invert_yaxis()

plt.xlabel('Count', fontsize=18)
plt.title('Data Sources', fontsize=20);

# %% [markdown]
# ## Rename columns

# %%
df = df.rename(columns = {"cocnumber":"coc_number",
  
                          "pit_tot_hless_pit_hud":"total_homeless", 
                          "pit_tot_shelt_pit_hud":"total_sheltered", 
                          "pit_tot_unshelt_pit_hud":"total_unsheltered",
                          "dem_pop_pop_census":"total_population",
  
                          "fhfa_hpi_2009":"house_price_index_2009", 
                          "ln_hou_mkt_medrent_xt":"log_median_rent", 
                          "hou_mkt_utility_xt":"utility_costs", 
                          "hou_mkt_burden_own_acs5yr_2017":"percentage_owners_cost_burden_2016", 
                          "hou_mkt_burden_sev_rent_acs_2017":"percentage_renters_severe_cost_burden_2016", 
                          "hou_mkt_rentshare_acs5yr_2017":"share_renters_2016", 
                          "hou_mkt_rentvacancy_xt":"rental_vacancy_rate", 
                          "hou_mkt_density_dummy":"high_housing_density", 
                          "hou_mkt_evict_count":"number_eviction", 
                          "hou_mkt_ovrcrowd_acs5yr_2017":"share_overcrowded_units_2016", 
                          "major_city":"city_or_urban", 
           
                          "econ_labor_unemp_rate_BLS":"rate_unemployment", 
                          "econ_labor_incineq_acs5yr_2017":"gini_coefficient_2016", 
                          "econ_labor_pov_pop_census_share":"poverty_rate",
           
                          "hou_pol_hudunit_psh_hud_share":"share_HUD_units", 
                          "hou_pol_occhudunit_psh_hud":"HUD_unit_occupancy_rate", 
                          "hou_mkt_homeage1940_xt":"share_built_before_1940",
           
                          "dem_soc_black_census":"total_black", 
                          "dem_soc_hispanic_census":"total_latino_hispanic", 
                          "dem_soc_asian_census":"total_asian", 
                          "dem_soc_pacific_census":"total_pacific_islander", 
                          "dem_pop_child_census":"total_population_0_19", 
                          "dem_pop_senior_census":"total_population_65_plus", 
                          "dem_pop_female_census":"total_female_population", 
                          "dem_pop_mig_census":"net_migration", 
                          "d_dem_pop_mig_census_share":"migration_4_year_change", 
                          "dem_soc_singadult_xt":"proportion_one_person_households", 
                          "dem_soc_singparent_xt":"share_under_18_with_single_parent", 
                          "dem_soc_vet_xt":"share_veteran_status", 
                          "dem_soc_ed_lessbach_xt":"share_no_bachelors", 
                          "dem_health_cost_dart":"medicare_reimbursements_per_enrollee", 
                          "dem_health_excesdrink_chr":"percentage_excessive_drinking",
           
                          "env_wea_avgtemp_noaa":"average_Jan_temperature", 
                          "env_wea_avgtemp_summer_noaa":"average_summer_temperature", 
                          "env_wea_precip_noaa":"total_Jan_precipitation", 
                          "env_wea_precip_annual_noaa":"total_annual_precipitation",
                          "hou_pol_fedfundcoc":"federal_funding",
                          "d_hou_pol_fedfundcoc":"federal_funding_change"})

# %% [markdown]
# ## Quality Control

# %% [markdown]
# Check for out-of-range values or values that are not useful for analysis. Either set values to `NaN` or remove the observations, as appropriate.

# %%
df.agg(['min','max'])
# Out:
#      year coc_number  total_homeless  total_sheltered  total_unsheltered  \
# min  2010     AK-500             7.0              3.0                0.0
# max  2017     WY-500         76501.0          72565.0            42828.0
#
#      total_population  house_price_index_2009  log_median_rent  utility_costs  \
# min             29344              -26.497087         1.239243            5.6
# max          11058958               63.864007         2.874838           22.6
#
#      percentage_owners_cost_burden_2016  ...  share_veteran_status  \
# min                            8.072322  ...              2.798413
# max                           22.955448  ...             23.876883
#
#      share_no_bachelors  medicare_reimbursements_per_enrollee  \
# min           23.686455                               6.03065
# max           88.644989                              17.94801
#
#      percentage_excessive_drinking  average_Jan_temperature  \
# min                       0.105147                -3.240000
# max                       0.294401                74.699997
#
#      average_summer_temperature  total_Jan_precipitation  \
# min                   55.799999                 0.000000
# max                   93.250000                25.321701
#
#      total_annual_precipitation  federal_funding  federal_funding_change
# min                    1.250000          0.00000              -56.846024
# max                  105.190002       1219.65844              280.022278
#
# [2 rows x 45 columns]

# %%
df.agg(['min','max']).T
# Out:
#                                                   min         max
# year                                             2010        2017
# coc_number                                     AK-500      WY-500
# total_homeless                                    7.0     76501.0
# total_sheltered                                   3.0     72565.0
# total_unsheltered                                 0.0     42828.0
# total_population                                29344    11058958
# house_price_index_2009                     -26.497087   63.864007
# log_median_rent                              1.239243    2.874838
# utility_costs                                     5.6        22.6
# percentage_owners_cost_burden_2016           8.072322   22.955448
# percentage_renters_severe_cost_burden_2016   16.38365   37.648594
# share_renters_2016                          15.101129   69.224808
# rental_vacancy_rate                          1.923865    24.62575
# high_housing_density                                0           1
# number_eviction                                     0       37105
# share_overcrowded_units_2016                 0.655098    12.26459
# city_or_urban                                       0           1
# suburban                                            0           1
# rate_unemployment                            2.511005   28.861258
# gini_coefficient_2016                       37.560001   54.779999
# poverty_rate                                 3.350358   35.789856
# share_HUD_units                              0.086669   13.962489
# HUD_unit_occupancy_rate                     69.444977       100.0
# share_built_before_1940                       0.22047   56.875412
# total_black                                       152     1956449
# total_latino_hispanic                             224     4924272
# total_asian                                        80     1474987
# total_pacific_islander                              1       89016
# total_population_0_19                            6194     3204024
# total_population_65_plus                         4781     1525916
# total_female_population                         14816     5542088
# net_migration                                  -41321      101369
# migration_4_year_change                     -3.446624    2.598058
# proportion_one_person_households            12.483664   46.710182
# share_under_18_with_single_parent            9.441208   55.627487
# share_veteran_status                         2.798413   23.876883
# share_no_bachelors                          23.686455   88.644989
# medicare_reimbursements_per_enrollee          6.03065    17.94801
# percentage_excessive_drinking                0.105147    0.294401
# average_Jan_temperature                         -3.24   74.699997
# average_summer_temperature                  55.799999       93.25
# total_Jan_precipitation                           0.0   25.321701
# total_annual_precipitation                       1.25  105.190002
# federal_funding                                   0.0  1219.65844
# federal_funding_change                     -56.846024  280.022278

# %% [markdown]
# ## Identify and deal with missing values

# %% [markdown]
# Determine whether there are missing values in the data set.

# %%
msno.bar(df)
# Out:
# <Axes: >

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %% [markdown]
# Since this project is aiming to predict the number of people experiencing homelessness, I'm removing the rows that those numbers are missing

# %%
df = df[df['total_homeless'].isna() == False]

# %%
df.isna().sum()
# Out:
# year                                             0
# coc_number                                       0
# total_homeless                                   0
# total_sheltered                                  0
# total_unsheltered                                0
# total_population                                 0
# house_price_index_2009                           0
# log_median_rent                               1495
# utility_costs                                 1495
# percentage_owners_cost_burden_2016               0
# percentage_renters_severe_cost_burden_2016       0
# share_renters_2016                               0
# rental_vacancy_rate                           1495
# high_housing_density                             0
# number_eviction                                  0
# share_overcrowded_units_2016                     0
# city_or_urban                                    0
# suburban                                         0
# rate_unemployment                                0
# gini_coefficient_2016                            0
# poverty_rate                                     0
# share_HUD_units                                  0
# HUD_unit_occupancy_rate                          0
# share_built_before_1940                       1495
# total_black                                      0
# total_latino_hispanic                            0
# total_asian                                      0
# total_pacific_islander                           0
# total_population_0_19                            0
# total_population_65_plus                         0
# total_female_population                          0
# net_migration                                    0
# migration_4_year_change                       2620
# proportion_one_person_households              1495
# share_under_18_with_single_parent             1495
# share_veteran_status                          1495
# share_no_bachelors                            1495
# medicare_reimbursements_per_enrollee             0
# percentage_excessive_drinking                 2620
# average_Jan_temperature                          0
# average_summer_temperature                       2
# total_Jan_precipitation                          0
# total_annual_precipitation                       0
# federal_funding                                  0
# federal_funding_change                        2620
# dtype: int64

# %% [markdown]
# There are some variables that are missing many of their values.
#
#
# A scatter plots of the variables that are missing many values vs. time to see if data are missing from particular years.

# %%
plt.plot(df['year'], df['percentage_excessive_drinking'], 'o');

# %%
df['year'].unique()
# Out:
# array([2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017])

# %%
plt.plot(df['year'], df['migration_4_year_change'], 'o');

# %% [markdown]
# Since `percentage_excessive_drinking` and `migration_4_year_change` only have data from 2017, I will focus on data from 2017.

# %%
df = df[df['year'] == 2017]

# %%
df.shape
# Out:
# (374, 45)

# %% [markdown]
# Check for missing values.

# %%
df.isna().sum()
# Out:
# year                                          0
# coc_number                                    0
# total_homeless                                0
# total_sheltered                               0
# total_unsheltered                             0
# total_population                              0
# house_price_index_2009                        0
# log_median_rent                               0
# utility_costs                                 0
# percentage_owners_cost_burden_2016            0
# percentage_renters_severe_cost_burden_2016    0
# share_renters_2016                            0
# rental_vacancy_rate                           0
# high_housing_density                          0
# number_eviction                               0
# share_overcrowded_units_2016                  0
# city_or_urban                                 0
# suburban                                      0
# rate_unemployment                             0
# gini_coefficient_2016                         0
# poverty_rate                                  0
# share_HUD_units                               0
# HUD_unit_occupancy_rate                       0
# share_built_before_1940                       0
# total_black                                   0
# total_latino_hispanic                         0
# total_asian                                   0
# total_pacific_islander                        0
# total_population_0_19                         0
# total_population_65_plus                      0
# total_female_population                       0
# net_migration                                 0
# migration_4_year_change                       0
# proportion_one_person_households              0
# share_under_18_with_single_parent             0
# share_veteran_status                          0
# share_no_bachelors                            0
# medicare_reimbursements_per_enrollee          0
# percentage_excessive_drinking                 0
# average_Jan_temperature                       0
# average_summer_temperature                    0
# total_Jan_precipitation                       0
# total_annual_precipitation                    0
# federal_funding                               0
# federal_funding_change                        0
# dtype: int64

# %% [markdown]
# ## Create relevant derived variables as new columns

# %% [markdown]
# Create new variables `rate_homeless`, `rate_sheltered`, and `rate_unsheltered` in the data frame `df_2017` that are the counts per 10,000 people in the population.

# %%
df['rate_homeless'] = df['total_homeless']/(df['total_population']/10_000)
df['rate_sheltered'] = df['total_sheltered']/(df['total_population']/10_000)
df['rate_unsheltered'] = df['total_unsheltered']/(df['total_population']/10_000)
# Out:
# <ipython-input-101-87b6e30b3656>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rate_homeless'] = df['total_homeless']/(df['total_population']/10_000)
# <ipython-input-101-87b6e30b3656>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rate_sheltered'] = df['total_sheltered']/(df['total_population']/10_000)
# <ipython-input-101-87b6e30b3656>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rate_unsheltered'] = df['total_unsheltered']/(df['total_population']/10_000)

# %% [markdown]
# We should note that the demographic variables (race, gender, age) are given as total counts. We will also convert these totals to percentages.

# %%
df['percent_black'] = df['total_black'] / df['total_population']
df['percent_latino_hispanic'] = df['total_latino_hispanic'] / df['total_population']
df['percent_asian'] = df['total_asian'] / df['total_population']
df['percent_pacific_islander'] = df['total_pacific_islander'] / df['total_population']
df['percent_population_0_19'] = df['total_population_0_19'] / df['total_population']
df['percent_population_65_plus'] = df['total_population_65_plus'] / df['total_population']
df['percent_female_population'] = df['total_female_population'] / df['total_population']
# Out:
# <ipython-input-102-bafbd3333d2c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['percent_black'] = df['total_black'] / df['total_population']
# <ipython-input-102-bafbd3333d2c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['percent_latino_hispanic'] = df['total_latino_hispanic'] / df['total_population']
# <ipython-input-102-bafbd3333d2c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['percent_asian'] = df['total_asian'] / df['total_population']
# <ipython-input-102-bafbd3333d2c>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['percent_pacific_islander'] = df['total_pacific_islander'] / df['total_population']
# <ipython-input-102-bafbd3333d2c>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['percent_population_0_19'] = df['total_population_0_19'] / df['total_population']
# <ipython-input-102-bafbd3333d2c>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['percent_population_65_plus'] = df['total_population_65_plus'] / df['total_population']
# <ipython-input-102-bafbd3333d2c>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['percent_female_population'] = df['total_female_population'] / df['total_population']

# %% [markdown]
# ## Export the clean .csv files

# %% [markdown]
# Export files with the training and testing data

# %%
from google.colab import files

df.to_csv('clean_homelessness.csv', encoding = 'utf-8-sig', index=False) 
files.download('clean_homelessness.csv')
